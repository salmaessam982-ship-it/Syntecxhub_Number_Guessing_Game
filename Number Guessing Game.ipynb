# %%
import random

# %%
def difficulty_level():
    print("Choose level of difficulty :")
    print("1.Easy range[1-50]")
    print("2.Medium range[1-100]")
    print("3.Hard range[1-500]")

    while True:
        choice = input("Enter a number : ")
        if choice == "1":
            return 50 
        elif choice == "2":
            return 100
        elif choice == "3":
            return 500
        else:
            print("Invalid choice")

# %%
def game(maximum):
    number = random.randint(1,maximum) 
    attempts = 0 
    print(f"\n I  have chosen a number between 1 & {maximum}")

    while True :
        try:
            guess = int(input("Enter your number :"))
        except ValueError:
            print("Enter a valid number ")
            continue
        if guess < 1 or guess > maximum :
            print(f"please enter a number between 1 & {maximum}")
            continue
        attempts += 1 
        if guess < number:
            print(f"Higher than : {guess}")
        elif guess > number:
            print(f"Lower than : {guess}")
        else:
            print(f"Correct , the number is {guess}")
            return attempts

# %%
def main():
    best_attempts = None
    print("Number Guess Game")
    while True :
        maximum = difficulty_level()
        attempts = game(maximum)
        if best_attempts is None or attempts < best_attempts:
            best_attempts = attempts
            print(f"new best attempts : {best_attempts}")
        else:
            print(f"best attempts : {best_attempts}")
        play_again = input("\n Do you want to play again?")

        if play_again != "yes":
            print("thanks for your playing")
            break
if __name__ == "__main__":
    main()
# Out:
# Number Guess Game
# Choose level of difficulty :
# 1.Easy range[1-50]
# 2.Medium range[1-100]
# 3.Hard range[1-500]
#
#  I  have chosen a number between 1 & 50
# Correct , the number is 40
# new best attempts : 1
# Choose level of difficulty :
# 1.Easy range[1-50]
# 2.Medium range[1-100]
# 3.Hard range[1-500]
#
#  I  have chosen a number between 1 & 50
# Lower than : 40
# Lower than : 39
# Lower than : 30
# Lower than : 20
# Lower than : 20
# Higher than : 10
# Higher than : 15
# Higher than : 16
# Higher than : 17
# Higher than : 18
# Correct , the number is 19
# best attempts : 1
# thanks for your playing
